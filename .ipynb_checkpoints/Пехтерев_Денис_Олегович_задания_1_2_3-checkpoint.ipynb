# %% [markdown]
# # 1. Написать программу, оценивающую значение машинного эпсилон для стандартных чисел с двойной точностью.

# %%
import numpy as np

# %matplotlib notebook

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
eps = 1

while 1 + eps/2 != 1:
    eps = eps/2
print ('value machine epsilon is', eps)
# Out:
# value machine epsilon is 2.220446049250313e-16

# %% [markdown]
# # 2. Привести пример функции, производную которой нельзя вычислить методом дифференцирования с комплексным шагом.

# %% [markdown]
# # 3. Релизовать алгоритм вычисления первой производной методом дифференцирования с комплексным шагом. Для функции с известным значением производной, изучить сходимость численного ответа при уменьшении шага.
#
# ### Формулой будет являться: $$
# f'(x) = \frac{ \mathrm{Im}\,f(x+ih) }{h} + O(h^2)
# $$
#
# Возьмём кое-что отсюда: https://blogs.mathworks.com/cleve/2013/10/14/complex-step-differentiation/

# %%
import math

h = 10^(-8)
def f_complex (x):
    f_x = math.e ** x / ((math.cos(x))**3 + (math.sin(x))**3)
    return f_x 
def f_complex_der (x,h):
    z = f_complex(x + h*1j) #x + hj
    f_x_der = z.imag/h
    return f_x_der 
xx = np.linspace(-math.pi/4, math.pi/2, num=80)
plt.plot(xx, [f_complex(x) for x in xx])    
plt.plot (math.pi/4, f_complex (math.pi/4), 'o-')
print (f_complex_der(math.pi/4,h))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in double_scalars
#   """
# <img src="data:image/png;base64,..." width="638.888905813665">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-4699611b81b9> in <module>()
#      12 plt.plot(xx, [f_complex(x) for x in xx])
#      13 plt.plot (math.pi/4, f_complex (math.pi/4), 'o-')
# ---> 14 print (f_complex_der(math.pi/4,h))
#
# <ipython-input-24-4699611b81b9> in f_complex_der(x, h)
#       6     return f_x
#       7 def f_complex_der (x,h):
# ----> 8     z = f_complex(x + h*1j) #x + hj
#       9     f_x_der = z.imag/h
#      10     return f_x_der
#
# <ipython-input-24-4699611b81b9> in f_complex(x)
#       3 h = 10^(-8)
#       4 def f_complex (x):
# ----> 5     f_x = math.e ** x / ((math.cos(x))**3 + (math.sin(x))**3)
#       6     return f_x
#       7 def f_complex_der (x,h):
#
# TypeError: can't convert complex to float

# %% [markdown]
# Окей, выбрали функцию, нарисовали график - пора наконец и производную найти :)
#
#
# Вычислить $$f'(x) = \frac{ \mathrm{Im}\,f(x+ih) }{h} + O(h^2)$$
